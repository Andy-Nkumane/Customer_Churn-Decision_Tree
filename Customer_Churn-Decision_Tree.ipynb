# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
customer_churn = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
customer_churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
customer_churn.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
y = customer_churn['Churn']
X = customer_churn[[x for x in customer_churn.columns if x != 'Churn']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)

# %% [markdown]
# ---

# %%
train_data = pd.concat([y_train, X_train], axis=1)
train_data.head()
# Out:
#      Churn  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1114    No  3312-UUMZW    Male              0     Yes         No      32
# 5499   Yes  4631-OACRM    Male              1      No         No      15
# 798     No  3807-XHCJH  Female              0     Yes        Yes       1
# 2558    No  5380-XPJNZ  Female              0      No         No      38
# 2305    No  4947-DSMXK    Male              0     Yes        Yes      34
#
#      PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 1114          Yes           Yes     Fiber optic  ...                  Yes
# 5499          Yes            No     Fiber optic  ...                   No
# 798           Yes            No              No  ...  No internet service
# 2558          Yes            No              No  ...  No internet service
# 2305          Yes           Yes     Fiber optic  ...                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 1114                   No                   No                  Yes
# 5499                   No                   No                   No
# 798   No internet service  No internet service  No internet service
# 2558  No internet service  No internet service  No internet service
# 2305                   No                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 1114                  Yes  Month-to-month              Yes
# 5499                  Yes  Month-to-month              Yes
# 798   No internet service  Month-to-month               No
# 2558  No internet service        One year               No
# 2305                  Yes  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges
# 1114    Credit card (automatic)          98.85        3145.9
# 5499           Electronic check          79.40        1156.1
# 798            Electronic check          20.00            20
# 2558               Mailed check          20.05         678.2
# 2305  Bank transfer (automatic)          97.70          3410
#
# [5 rows x 21 columns]

# %%
train_data.isnull().sum()
# Out:
# Churn               0
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# dtype: int64

# %%
lb = LabelEncoder()

for i in train_data.columns:
    yes = 'Yes' in list(train_data[i].unique())
    no = 'No' in list(train_data[i].unique())
    if yes and no and len(train_data[i].unique()) == 2:
        train_data[i] = lb.fit_transform(train_data[i])

# %%
train_data.head()
# Out:
#       Churn  customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 1114      0  3312-UUMZW    Male              0        1           0      32
# 5499      1  4631-OACRM    Male              1        0           0      15
# 798       0  3807-XHCJH  Female              0        1           1       1
# 2558      0  5380-XPJNZ  Female              0        0           0      38
# 2305      0  4947-DSMXK    Male              0        1           1      34
#
#       PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 1114             1           Yes     Fiber optic  ...                  Yes
# 5499             1            No     Fiber optic  ...                   No
# 798              1            No              No  ...  No internet service
# 2558             1            No              No  ...  No internet service
# 2305             1           Yes     Fiber optic  ...                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 1114                   No                   No                  Yes
# 5499                   No                   No                   No
# 798   No internet service  No internet service  No internet service
# 2558  No internet service  No internet service  No internet service
# 2305                   No                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 1114                  Yes  Month-to-month                1
# 5499                  Yes  Month-to-month                1
# 798   No internet service  Month-to-month                0
# 2558  No internet service        One year                0
# 2305                  Yes  Month-to-month                1
#
#                   PaymentMethod MonthlyCharges  TotalCharges
# 1114    Credit card (automatic)          98.85        3145.9
# 5499           Electronic check          79.40        1156.1
# 798            Electronic check          20.00            20
# 2558               Mailed check          20.05         678.2
# 2305  Bank transfer (automatic)          97.70          3410
#
# [5 rows x 21 columns]

# %% [markdown]
# ---
